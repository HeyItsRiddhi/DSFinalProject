# %% [markdown]
# # Baseline Classifier Evaluation
#
# ** uses nltk Max Entropy classifier **
#
# original algorithm here: https://github.com/kitofans/ethnicityguesser
#
#
# ** TOC **
#
# 1. Import & Clean Name Data
# 2. EDA on Name Data
# 3. Training the Baseline Model
# 4. Evaluating the Baseline Model

# %%
from ethnicityguesser.NLTKMaxentEthnicityClassifier import NLTKMaxentEthnicityClassifier as mxec
from os import walk
import pandas as pd
import csv
import pickle
import numpy as np

# %% [markdown]
# # 1. Import & Clean Name Data

# %%
## Import names paired with ethnicities ##

# find names of files
f = []
for (dirpath, dirnames, filenames) in walk("ethnicityguesser/pickled_names"):
    f.extend(filenames)
    break

# list types of ethnicities
ethnicities = []
for each in f:
    ethnicities.append(each.partition('.')[0])


# pair type of ethnicity to its names in a dict
eth_dict = {}
for ethnicity in ethnicities:
    with open('ethnicityguesser/pickled_names/'+ethnicity+'.pkl', 'rb') as filename:
        names = pickle.load(filename)
    eth_dict[ethnicity] = names

# %%
ethnicities
# Out:
# ['chinese',
#  'vietnamese',
#  'irish',
#  'danish',
#  'french',
#  'russian',
#  'japanese',
#  'german',
#  'czech',
#  'arabic',
#  'ukranian',
#  'swedish',
#  'spanish',
#  'african',
#  'swiss',
#  'korean',
#  'jewish',
#  'greek',
#  'italian',
#  'slavic',
#  'indian',
#  'muslim',
#  'portugese']

# %%
## make a super list of names and true ethnicities

super_list_names = []
super_list_ethnicities = []

for ethnicity in ethnicities:
    name_list = eth_dict[ethnicity][0]
    eth_list = []
    for name in name_list:
        eth_list.append(ethnicity)
    super_list_names = super_list_names + name_list
    super_list_ethnicities = super_list_ethnicities + eth_list
    
df = pd.DataFrame(
            {'Name': super_list_names,
             'True Ethnicity': super_list_ethnicities
            })

# %% [markdown]
# # 2. EDA on Name Data
#
# Let's examine what our name data looks like in reality.

# %%
df.sample(frac=1).head(10)
# Out:
#            Name True Ethnicity
# 9458   Grinberg        swedish
# 7489      Herda          czech
# 19557      Caro      portugese
# 13215     Guell          swiss
# 13208   Grunder          swiss
# 2000      Bonet         french
# 13994  Awerbuch         jewish
# 17392      Agli        italian
# 11597    Mejias        spanish
# 2349     Chabot         french

# %% [markdown]
# Let's compare the data we have for every ethnicity.

# %%
print "n for each ethnicity sample"
for ethnicity in ethnicities:
    print len(df[df['True Ethnicity']==ethnicity]), ethnicity
# Out:
# n for each ethnicity sample
# 426 chinese
# 129 vietnamese
# 318 irish
# 656 danish
# 4143 french
# 181 russian
# 566 japanese
# 723 german
# 1406 czech
# 108 arabic
# 409 ukranian
# 1158 swedish
# 2366 spanish
# 300 african
# 774 swiss
# 169 korean
# 3076 jewish
# 429 greek
# 711 italian
# 258 slavic
# 580 indian
# 525 muslim
# 834 portugese
# 23

# %% [markdown]
# Choosing between 23 specific ethnicities accurately is more difficult than choosing between around 5 or 6 broad defined ethnicities because (1) having more choices to choose from in general creates more opportunities for classification errors, and (2) some ethnicities from similar parts of the world have overlapping names (like "Alexander" is a common Danish, Greek, and French name).
#
# Let's consolidate some groups that share name/cultural similarities. Let's also make equal sample sizes for each consolidated group, drawing evenly from each subgroup to prevent our classifier from ignoring "low frequency" ethnicities.

# %%
temp_df = pd.DataFrame(columns=['Name', 'True Ethnicity'])

target_df = temp_df
eth_list = ['danish', 'french', 'italian']

sample_df = pd.DataFrame(columns=['Name', 'True Ethnicity'])
for ethnicity in eth_list:
    eth_df = df[df['True Ethnicity']==ethnicity]
    n_per_eth = (1000 / len(eth_list))
    print n_per_eth
    sample_df = pd.concat([sample_df, eth_df.sample(n=n_per_eth)])

target_df = pd.concat([target_df,sample_df]) 

target_df['True Ethnicity'] = "white"
# Out:
# 333
# 333
# 333

# %%
ethnicities
# Out:
# ['chinese',
#  'vietnamese',
#  'irish',
#  'danish',
#  'french',
#  'russian',
#  'japanese',
#  'german',
#  'czech',
#  'arabic',
#  'ukranian',
#  'swedish',
#  'spanish',
#  'african',
#  'swiss',
#  'korean',
#  'jewish',
#  'greek',
#  'italian',
#  'slavic',
#  'indian',
#  'muslim',
#  'portugese']

# %%
# Consolidation function

df_c = pd.DataFrame(columns=['Name', 'True Ethnicity'])

def consolidate(eth_list, target_df, consolidated_eth):
    sample_df = pd.DataFrame(columns=['Name', 'True Ethnicity'])
    for ethnicity in eth_list:
        eth_df = df[df['True Ethnicity']==ethnicity]
        n_per_eth = (1000 / len(eth_list))
        sample_df = pd.concat([sample_df, eth_df.sample(n=n_per_eth, replace = True)])
    sample_df['True Ethnicity'] = consolidated_eth
    return pd.concat([target_df,sample_df]) 


# Consolidate East European
east_euro = ['russian','ukranian','czech','slavic']
df_c = consolidate(east_euro, df_c, 'Eastern European')

# Consolidate West European
west_euro = ['italian','irish','danish','french',
                'swedish','german','swiss']
df_c = consolidate(west_euro, df_c, 'Western European')

# Consolidate Muslim / Arab
muslim_arabic = ['muslim', 'arabic']
df_c = consolidate(muslim_arabic, df_c, 'Muslim/Arabic')

# Consolidate East Asian
east_asian = ['chinese','japanese','vietnamese','korean']
df_c = consolidate(east_asian, df_c, 'East Asian')

# Spanish / Hispanic can remain its own category
hispanic = ['spanish','portugese'] 
df_c = consolidate(hispanic, df_c, 'Hispanic')

# Jewish can remain its own category
jewish = ['jewish']
df_c = consolidate(jewish, df_c, 'Jewish')

# Indian can remain its own category
indian = ['indian']
df_c = consolidate(indian, df_c, 'Indian')

# African can remain its own category 
african = ['african']
df_c = consolidate(african, df_c, 'African')

print 'Cleaned sample size:', len(df_c)
df_c.sample(n=10)
# Out:
# Cleaned sample size: 7994
#              Name True Ethnicity
# 18894        Abdi  Muslim/Arabic
# 10846       Cobos       Hispanic
# 16637       Vidal         Jewish
# 11767    Napoleon       Hispanic
# 12599      Adanna        African
# 18334         Bal         Indian
# 18730  Rampersaud         Indian
# 18520     Jhaveri         Indian
# 18948       Assaf  Muslim/Arabic
# 8607        Koury  Muslim/Arabic

# %%
## List Consolidated Ethnicities
ethnicities_c = [
    'Eastern European',
    'Western European',
    'Muslim/Arabic',
    'East Asian',
    'Hispanic',
    'Jewish',
    'Indian',
    'African'
]

# %% [markdown]
# # 3. Train the Model

# %%
## Split into Training and Test
msk = np.random.rand(len(df_c)) < 0.5
train_df = df_c[msk]
test_df = df_c[~msk]

print "Total Sample (n)", len (df_c)
print "Test Sample (test n)", len(test_df)
print "Train Sample (train n)", len(train_df)
# Out:
# Total Sample (n) 7994
# Test Sample (test n) 3894
# Train Sample (train n) 4100

# %%
## Package DF into training token
train_tokens = []
for ethnicity in ethnicities_c:
    new_tokens = (list(train_df[train_df['True Ethnicity'] == ethnicity]['Name']), ethnicity)
    train_tokens.append(new_tokens)

# (Tokens must be a list of ([list of names], 'ethnicity') pairs.)

# %%
## Train Classifier (beware, this takes time)

classifier = mxec(train_tokens)
classifier.train()
# Out:
#   ==> Training (100 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -2.07944        0.122
#              2          -1.14179        0.929
#              3          -0.78956        0.950
#              4          -0.61208        0.966
#              5          -0.50362        0.977
#              6          -0.42959        0.982
#              7          -0.37544        0.986
#              8          -0.33392        0.988
#              9          -0.30099        0.990
#             10          -0.27420        0.990
#             11          -0.25196        0.991
#             12          -0.23319        0.991
#             13          -0.21713        0.991
#             14          -0.20324        0.991
#             15          -0.19109        0.991
#             16          -0.18039        0.992
#             17          -0.17088        0.992
#             18          -0.16238        0.992
#             19          -0.15473        0.992
#             20          -0.14781        0.992
#             21          -0.14153        0.992
#             22          -0.13579        0.992
#             23          -0.13054        0.992
#             24          -0.12570        0.992
#             25          -0.12124        0.992
#             26          -0.11711        0.992
#             27          -0.11328        0.992
#             28          -0.10971        0.992
#             29          -0.10638        0.992
#             30          -0.10326        0.992
#             31          -0.10034        0.992
#             32          -0.09760        0.992
#             33          -0.09502        0.992
#             34          -0.09258        0.992
#             35          -0.09028        0.992
#             36          -0.08811        0.992
#             37          -0.08605        0.992
#             38          -0.08410        0.992
#             39          -0.08224        0.992
#             40          -0.08048        0.992
#             41          -0.07879        0.992
#             42          -0.07719        0.992
#             43          -0.07566        0.992
#             44          -0.07420        0.992
#             45          -0.07280        0.992
#             46          -0.07146        0.992
#             47          -0.07018        0.992
#             48          -0.06895        0.992
#             49          -0.06777        0.992
#             50          -0.06663        0.992
#             51          -0.06554        0.992
#             52          -0.06449        0.992
#             53          -0.06348        0.992
#             54          -0.06250        0.992
#             55          -0.06156        0.992
#             56          -0.06065        0.992
#             57          -0.05978        0.992
#             58          -0.05893        0.992
#             59          -0.05811        0.992
#             60          -0.05732        0.992
#             61          -0.05656        0.992
#             62          -0.05581        0.992
#             63          -0.05510        0.992
#             64          -0.05440        0.992
#             65          -0.05372        0.992
#             66          -0.05307        0.992
#             67          -0.05243        0.992
#             68          -0.05181        0.992
#             69          -0.05121        0.992
#             70          -0.05063        0.992
#             71          -0.05006        0.992
#             72          -0.04951        0.992
#             73          -0.04898        0.992
#             74          -0.04845        0.992
#             75          -0.04795        0.992
#             76          -0.04745        0.992
#             77          -0.04697        0.992
#             78          -0.04650        0.992
#             79          -0.04604        0.992
#             80          -0.04559        0.992
#             81          -0.04515        0.992
#             82          -0.04473        0.992
#             83          -0.04431        0.992
#             84          -0.04390        0.992
#             85          -0.04351        0.992
#             86          -0.04312        0.992
#             87          -0.04274        0.992
#             88          -0.04237        0.992
#             89          -0.04201        0.992
#             90          -0.04165        0.992
#             91          -0.04131        0.992
#             92          -0.04097        0.992
#             93          -0.04063        0.992
#             94          -0.04031        0.992
#             95          -0.03999        0.992
#             96          -0.03968        0.992
#             97          -0.03937        0.992
#             98          -0.03907        0.992
#             99          -0.03878        0.992
#          Final          -0.03849        0.992

# %%
# Test Classifier
print classifier.classify('Michael')
print classifier.classify('Roberto')
print classifier.classify('Lee')
print classifier.classify('sajkfldsafh')

def prob(name):
    return classifier.prob_classify(name)._prob_dict.items()
    #return max((p,v) for (v,p) in classifier.prob_classify(name)._prob_dict.items())

# find probability of prediction as log (lower is better)
print prob('Michael')
#print prob('Roberto')
#print prob('Lee')
#print prob('sajkfldsafh')
# Out:
# Western European
# Hispanic
# East Asian
# Muslim/Arabic
# [('Eastern European', -3.7065529482840653), ('Jewish', -6.6514402039659508), ('Western European', -0.16855233603485154), ('African', -11.308063175888986), ('Hispanic', -7.7907496492955053), ('Indian', -8.3545578338112048), ('East Asian', -6.0727470332155962), ('Muslim/Arabic', -10.121878347922477)]

# %%
## Predict!!!!

test_names = list(test_df['Name'])
test_eth = list(test_df['True Ethnicity'])

test_preds = []

for name in test_names:
    pred = classifier.classify(name)
    test_preds.append(pred)

df_preds = pd.DataFrame({
    'Name': test_names,
    'True Ethnicity': test_eth,
    'Prediction': test_preds
})

df_preds.sample(15)
# Out:
#            Name        Prediction    True Ethnicity
# 419     Triebel  Western European  Eastern European
# 1386     Hakimi     Muslim/Arabic     Muslim/Arabic
# 2639     Alpron  Western European            Jewish
# 1978     Apollo          Hispanic          Hispanic
# 2899      Baria          Hispanic            Indian
# 3379    Shankar            Indian            Indian
# 2741  Zimbalist            Jewish            Jewish
# 1314     Mifsud     Muslim/Arabic     Muslim/Arabic
# 1589    Muraoka        East Asian        East Asian
# 479     Acconci  Western European  Western European
# 99     Chernoff            Jewish  Eastern European
# 172      Petrik  Eastern European  Eastern European
# 1955      Magro          Hispanic          Hispanic
# 3786    Kwabena           African           African
# 563   Mccormick  Western European  Western European

# %%
# Add True if you got it right
df_preds['Accuracy'] = (df_preds['Prediction']==df_preds['True Ethnicity'])
df_preds.sample(15)
# Out:
#             Name        Prediction    True Ethnicity  Accuracy
# 1368       Koury     Muslim/Arabic     Muslim/Arabic      True
# 2245   De Araujo          Hispanic          Hispanic      True
# 1092    Siddiqui     Muslim/Arabic     Muslim/Arabic      True
# 2399     Tzarfat            Jewish            Jewish      True
# 2872     Chazzan            Jewish            Jewish      True
# 113        Urban  Eastern European  Eastern European      True
# 1345      Atiyeh     Muslim/Arabic     Muslim/Arabic      True
# 3146    Upadhyay            Indian            Indian      True
# 3215    Sundaram            Jewish            Indian     False
# 3801  Oluwatoyin           African           African      True
# 2625       Kohen            Jewish            Jewish      True
# 1862         Kim     Muslim/Arabic        East Asian     False
# 2308   Marcelino          Hispanic          Hispanic      True
# 2249       Velez          Hispanic          Hispanic      True
# 3090         Ray            Indian            Indian      True

# %% [markdown]
# # 4. Evaluate the Model

# %%
## Tool to Calculate Accuracy Rates

def calcAccuracy(df):
    length = len(df)
    length_true = len(df[df['Accuracy']==True])
    return float(length_true)/float(length)

def calcTP(df, eth):
    length = df[df['True Ethnicity']==]

# %%
accuracies = []
TP = [] # number of times predict X when  X ethnicity
FP = [] # number of times predict X when 'X ethnicity
TN = [] # number of times predict'X when 'X ethnicity
FN = [] # number of times predict'X when  X ethnicity


ethnicity_list = []

# Classification Accuracy
for ethnicity in ethnicities_c:
    accuracy = calcAccuracy(df_preds[df_preds['True Ethnicity']==ethnicity])
    accuracies.append(accuracy)
    ethnicity_list.append(ethnicity)

# Aggregate accuracy
accuracies.append(calcAccuracy(df_preds))
ethnicity_list.append('OVERALL')

# put into df
df_acc = pd.DataFrame({
    'True Ethnicity': ethnicity_list,
    'Classification Accuracy': accuracies
})

df_acc.set_index('True Ethnicity', inplace=True)

# %%
df_acc
# Out:
#                   Classification Rate
# True Ethnicity
# Eastern European             0.737418
# Western European             0.577236
# Muslim/Arabic                0.852590
# East Asian                   0.789130
# Hispanic                     0.776639
# Jewish                       0.520243
# Indian                       0.760784
# African                      0.947047
# OVERALL                      0.744992

# %% [markdown]
# Using

# %%
df_voters = pd.read_csv('Milestone33.csv', sep='\t')
df_voters
# Out:
#       Unnamed: 0  Unnamed: 0.1    index district         id   LAST_NAME  \
# 0              0             0  4581539      DUV  103746250    Jennings
# 1              1             1  6399633      DUV  103699536  Nellenbach
# 2              2             2  5068762      DUV  103823224        YORK
# 3              3             3  2390889      CLA  102858200        SUCO
# 4              4             4  7092052      DUV  103844317       Amato
# 5              8             8  7621091      DUV  120286726       Gadio
# 6              9             9  4305830      DUV  114831837      Schaap
# 7             10            10  2075069      CLA  102861065       DOXEY
# 8             11            11   206657      BAY  116352668       LOGAN
# 9             12            12  7439038      DUV  103580214      Thomas
# 10            13            13  6210491      DUV  103737024       Zilla
# 11            15            15  6121393      DUV  103689734      Brooks
# 12            18            18  4137718      DES  103212920      Ridley
# 13            19            19   590042      BAY  100672916      MAPLES
# 14            25            25  7937893      DUV  103313626       Kelly
# 15            30            30  4375184      DUV  103607864      Walker
# 16            32            32  6572362      DUV  103553305     DLUGOSZ
# 17            33            33  1913637      CLA  102809429      BETHEL
# 18            37            37  2038748      CLA  102819585   SCIUMBATA
# 19            39            39  3849066      CLL  116983070     Airoldi
# 20            40            40  2439249      CLA  118212648       RALEY
# 21            43            43  2534421      CLA  102846025       OLSON
# 22            45            45  2335245      CLA  102872524        TRAN
# 23            48            48  2061410      CLA  102913142     PERKINS
# 24            49            49  4207205      DES  103223519       Banks
# 25            52            52   772744      BAY  100685685        FREE
# 26            53            53  3858915      CLL  103062775       Riley
# 27            56            56  4272966      DIX  103237681    Endicott
# 28            57            57  2470241      CLA  102892230      TORRES
# 29            61            61  4419959      DUV  103281151      Surles
# ...          ...           ...      ...      ...        ...         ...
# 5116        9952          9952  5798638      DUV  103404206     Sherrod
# 5117        9954          9954  4982624      DUV  117010840   Stevenson
# 5118        9956          9956  4176113      DES  103222372      Zipper
# 5119        9958          9958  5831868      DUV  103443630   LUCARELLI
# 5120        9959          9959  3843253      CLL  103057805       Gates
# 5121        9960          9960  6805959      DUV  103395694    Gasparre
# 5122        9961          9961  2713876      CLL  122701471   Rodriguez
# 5123        9962          9962  7529612      DUV  103614979      Paraso
# 5124        9963          9963   370635      BAY  100643092    STERRETT
# 5125        9966          9966  5832495      DUV  103485379       Frost
# 5126        9967          9967  3323167      CLL  121733308       Delpo
# 5127        9968          9968  7255266      DUV  103535798    Douglass
# 5128        9969          9969  7831328      DUV  103392969        Huth
# 5129        9971          9971  3065852      CLL  103082525        Wood
# 5130        9972          9972  3677451      CLL  103121131       GOODS
# 5131        9973          9973  4359647      DUV  103431973        Clay
# 5132        9976          9976  6013364      DUV  114629338      Grubbs
# 5133        9977          9977  6743016      DUV  103295354       Jones
# 5134        9978          9978  8152628      DUV  103720565       Bryan
# 5135        9980          9980  3744572      CLL  114702249      Guerra
# 5136        9984          9984  4179595      DES  111951071       James
# 5137        9985          9985   133593      BAY  100608917      HIGDON
# 5138        9986          9986  1067836      CAL  102532655    Ethridge
# 5139        9987          9987  2822700      CLL  116582642    Kowalski
# 5140        9988          9988  6382679      DUV  103296082      Barton
# 5141        9990          9990  7887207      DUV  103426257     Schmidt
# 5142        9994          9994  3001732      CLL  103139979      Caruso
# 5143        9995          9995   988823      BRA  100737757     Padgett
# 5144        9997          9997   410368      BAY  100688951   WIBBERLEY
# 5145        9998          9998  1836694      CLA  102919286        DIAZ
#
#        FIRST_NAME        zip female                  dob     regyear party  \
# 0         Barbara      32225      F  1944-05-23 00:00:00  08/12/2004   REP
# 1         Marlene      32223      F  1944-07-04 00:00:00  09/03/1996   NPA
# 2          MARTHA      32246      F  1948-02-10 00:00:00  10/05/1992   REP
# 3          BRANDI      32656      F  1981-09-25 00:00:00  05/16/2000   IDP
# 4            Lisa      32250      F  1972-09-14 00:00:00  10/01/2004   DEM
# 5           Adama      32206      F  1989-06-01 00:00:00  09/21/2012   DEM
# 6          Carole      32257      F  1942-02-04 00:00:00  11/28/2006   INT
# 7          VICKEY      32656      F  1961-08-20 00:00:00  08/28/2000   REP
# 8         JESSICA      32405      F  1987-10-06 00:00:00  07/01/2008   REP
# 9             Kim      32209      F  1960-04-09 00:00:00  07/31/2003   DEM
# 10        Michael      32210      M  1976-12-06 00:00:00  12/29/1995   REP
# 11      Stephanie      32209      F  1965-01-11 00:00:00  07/07/1983   DEM
# 12        Charles      34266      M  1936-09-26 00:00:00  01/24/1976   DEM
# 13         RACHEL      32405      F  1977-02-24 00:00:00  02/20/1998   REP
# 14           Tiny      32219      U  1978-11-21 00:00:00  04/17/2003   DEM
# 15         Bonnie      32218      F  1950-01-06 00:00:00  08/22/2003   REP
# 16          DEBRA      32246      F  1961-05-22 00:00:00  10/05/1992   REP
# 5139   11/08/2016     GEN          A  94.0      1      0
# 5140   11/04/2014     GEN          Y  57.0      0      0
# 5141   11/06/2012     GEN          Y  46.0      0      0
# 5142   11/02/2010     GEN          Y  87.0      0      0
# 5143   11/04/2008     GEN          Y  46.0      0      1
# 5144   11/04/2008     GEN          Y  45.0      0      1
# 5145   11/02/2010     GEN          Y  57.0      0      0
#
# [5146 rows x 18 columns]

# %% [markdown]
# # Additional EDA

# %%
# Add predictions to voter data
ethnicity_predictions = []
for name in list(df_voters['LAST_NAME']):
    ethnicity_predictions.append(classifier.classify(name))
    
ethnicity_predictions
# Out:
# ['Jewish',
#  'Jewish',
#  'Jewish',
#  'African',
#  'African',
#  'Hispanic',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Indian',
#  'Eastern European',
#  'Jewish',
#  'Western European',
#  'Eastern European',
#  'Western European',
#  'Jewish',
#  'Hispanic',
#  'Jewish',
#  'Muslim/Arabic',
#  'African',
#  'Eastern European',
#  'Jewish',
#  'East Asian',
#  'Jewish',
#  'Eastern European',
#  'East Asian',
#  'Eastern European',
#  'Western European',
#  'Hispanic',
#  'Jewish',
#  'Hispanic',
#  'East Asian',
#  'Jewish',
#  'Hispanic',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'East Asian',
#  'Western European',
#  'Jewish',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Jewish',
#  'African',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Hispanic',
#  'Western European',
#  'Western European',
#  'Hispanic',
#  'Indian',
#  'East Asian',
#  'East Asian',
#  'Eastern European',
#  'Eastern European',
#  'Hispanic',
#  'Hispanic',
#  'Western European',
#  'Western European',
#  'East Asian',
#  'Hispanic',
#  'Hispanic',
#  'Western European',
#  'Hispanic',
#  'Jewish',
#  'Jewish',
#  'Hispanic',
#  'Muslim/Arabic',
#  'Eastern European',
#  'Western European',
#  'Eastern European',
#  'Jewish',
#  'Indian',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Muslim/Arabic',
#  'Western European',
#  'African',
#  'Jewish',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Western European',
#  'East Asian',
#  'Eastern European',
#  'East Asian',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Jewish',
#  'Jewish',
#  'Eastern European',
#  'Indian',
#  'Western European',
#  'Eastern European',
#  'Jewish',
#  'Western European',
#  'Eastern European',
#  'Western European',
#  'Eastern European',
#  'Western European',
#  'Jewish',
#  'Indian',
#  'Jewish',
#  'Eastern European',
#  'Jewish',
#  'Western European',
#  'Hispanic',
#  'Eastern European',
#  'Western European',
#  'Jewish',
#  'East Asian',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Indian',
#  'Muslim/Arabic',
#  'Hispanic',
#  'Western European',
#  'Hispanic',
#  'Western European',
#  'Jewish',
#  'Jewish',
#  'Indian',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Hispanic',
#  'Muslim/Arabic',
#  'Eastern European',
#  'Jewish',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Hispanic',
#  'Hispanic',
#  'African',
#  'Indian',
#  'Indian',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Eastern European',
#  'Jewish',
#  'Jewish',
#  'Hispanic',
#  'Western European',
#  'Hispanic',
#  'Jewish',
#  'Hispanic',
#  'Western European',
#  'Jewish',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Hispanic',
#  'Hispanic',
#  'Western European',
#  'East Asian',
#  'Western European',
#  'Eastern European',
#  'Hispanic',
#  'Hispanic',
#  'Muslim/Arabic',
#  'Muslim/Arabic',
#  'Western European',
#  'Indian',
#  'Jewish',
#  'Eastern European',
#  'Jewish',
#  'Western European',
#  'East Asian',
#  'Eastern European',
#  'East Asian',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Jewish',
#  'Jewish',
#  'East Asian',
#  'Western European',
#  'Muslim/Arabic',
#  'Jewish',
#  'Jewish',
#  'Eastern European',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'East Asian',
#  'Indian',
#  'Western European',
#  'Western European',
#  'Jewish',
#  'Hispanic',
#  'Eastern European',
#  'Western European',
#  'Hispanic',
#  'Western European',
#  'Indian',
#  'Muslim/Arabic',
#  'Jewish',
#  'Hispanic',
#  'Indian',
#  'Jewish',
#  'Indian',
#  'Indian',
#  'East Asian',
#  'Hispanic',
#  'Hispanic',
#  'Jewish',
#  'Hispanic',
#  'Western European',
#  'Western European',
#  'Hispanic',
#  'Western European',
#  'Western European',
#  'Muslim/Arabic',
#  'African',
#  'Western European',
#  'Hispanic',
#  'Jewish',
#  'Eastern European',
#  'Hispanic',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'East Asian',
#  'Hispanic',
#  'Western European',
#  'Indian',
#  'Western European',
#  'Jewish',
#  'Eastern European',
#  'Jewish',
#  'Western European',
#  'Jewish',
#  'Eastern European',
#  'Western European',
#  'African',
#  'Indian',
#  'Muslim/Arabic',
#  'Western European',
#  'Indian',
#  'African',
#  'East Asian',
#  'Muslim/Arabic',
#  'East Asian',
#  'Eastern European',
#  'Jewish',
#  'Muslim/Arabic',
#  'Western European',
#  'Western European',
#  'East Asian',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Indian',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Muslim/Arabic',
#  'Hispanic',
#  'Western European',
#  'Western European',
#  'Eastern European',
#  'Western European',
#  'Western European',
#  'Muslim/Arabic',
#  'Hispanic',
#  'Western European',
#  'East Asian',
#  'Jewish',
#  'Hispanic',
#  'Jewish',
#  'Western European',
#  'Eastern European',
#  'Muslim/Arabic',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Indian',
#  'Western European',
#  'Eastern European',
#  'Western European',
#  'Hispanic',
#  'Jewish',
#  'Jewish',
#  'Indian',
#  'Western European',
#  'Western European',
#  'Hispanic',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Jewish',
#  'Muslim/Arabic',
#  'Indian',
#  'Hispanic',
#  'Eastern European',
#  'Indian',
#  'Muslim/Arabic',
#  'Jewish',
#  'Eastern European',
#  'Jewish',
#  'Hispanic',
#  'Jewish',
#  'Western European',
#  'Hispanic',
#  'East Asian',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'East Asian',
#  'Hispanic',
#  'Jewish',
#  'Western European',
#  'Hispanic',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Eastern European',
#  'African',
#  'Eastern European',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Hispanic',
#  'Eastern European',
#  'Western European',
#  'Western European',
#  'Jewish',
#  'Hispanic',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Hispanic',
#  'Western European',
#  'East Asian',
#  'Hispanic',
#  'Hispanic',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Indian',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Indian',
#  'Hispanic',
#  'Eastern European',
#  'Eastern European',
#  'Jewish',
#  'Jewish',
#  'Eastern European',
#  'Western European',
#  'Hispanic',
#  'Jewish',
#  'Muslim/Arabic',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Muslim/Arabic',
#  'Eastern European',
#  'East Asian',
#  'East Asian',
#  'Eastern European',
#  'Western European',
#  'Jewish',
#  'East Asian',
#  'Western European',
#  'Muslim/Arabic',
#  'Western European',
#  'Jewish',
#  'East Asian',
#  'Muslim/Arabic',
#  'Indian',
#  'East Asian',
#  'Eastern European',
#  'Western European',
#  'Western European',
#  'Hispanic',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Hispanic',
#  'Hispanic',
#  'Jewish',
#  'Jewish',
#  'Muslim/Arabic',
#  'Eastern European',
#  'Western European',
#  'Western European',
#  'Jewish',
#  'Jewish',
#  'Muslim/Arabic',
#  'Muslim/Arabic',
#  'Indian',
#  'East Asian',
#  'Western European',
#  'East Asian',
#  'Western European',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Eastern European',
#  'Western European',
#  'Indian',
#  'Western European',
#  'Western European',
#  'Hispanic',
#  'Hispanic',
#  'Jewish',
#  'Western European',
#  'Jewish',
#  'Jewish',
#  'Jewish',
#  'Hispanic',
#  'Jewish',
#  'Eastern European',
#  'Western European',
#  'Indian',
#  'Western European',
#  'Hispanic',
#  'East Asian',
#  'Muslim/Arabic',
#  'Western European',
#  'East Asian',
#  'Indian',
#  'Eastern European',
#  'Eastern European',
#  'Western European',
#  'Indian',
#  'Jewish',
#  'East Asian',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Indian',
#  'Hispanic',
#  'Indian',
#  'Western European',
#  'Western European',
#  'Hispanic',
#  'Jewish',
#  'Western European',
#  'Indian',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Jewish',
#  'African',
#  'Muslim/Arabic',
#  'Western European',
#  'East Asian',
#  'Eastern European',
#  'Hispanic',
#  'Western European',
#  'Western European',
#  'Muslim/Arabic',
#  'Eastern European',
#  'Indian',
#  'Western European',
#  'Eastern European',
#  'Hispanic',
#  'Western European',
#  'Jewish',
#  'Jewish',
#  'Muslim/Arabic',
#  'Jewish',
#  'African',
#  'Jewish',
#  'Eastern European',
#  'East Asian',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Indian',
#  'Indian',
#  'Jewish',
#  'Western European',
#  'Jewish',
#  'Muslim/Arabic',
#  'Jewish',
#  'Jewish',
#  'Jewish',
#  'Western European',
#  'Jewish',
#  'Indian',
#  'Indian',
#  'African',
#  'Eastern European',
#  'Jewish',
#  'Jewish',
#  'Hispanic',
#  'Western European',
#  'Eastern European',
#  'Eastern European',
#  'African',
#  'Jewish',
#  'Western European',
#  'Indian',
#  'Eastern European',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Hispanic',
#  'East Asian',
#  'Western European',
#  'Western European',
#  'Eastern European',
#  'Hispanic',
#  'Western European',
#  'East Asian',
#  'Jewish',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'East Asian',
#  'Western European',
#  'Jewish',
#  'Hispanic',
#  'Western European',
#  'Western European',
#  'Hispanic',
#  'Jewish',
#  'Hispanic',
#  'Western European',
#  'Jewish',
#  'Hispanic',
#  'Eastern European',
#  'Jewish',
#  'Hispanic',
#  'Hispanic',
#  'Hispanic',
#  'Hispanic',
#  'Indian',
#  'Western European',
#  'East Asian',
#  'Jewish',
#  'Eastern European',
#  'Western European',
#  'Jewish',
#  'Indian',
#  'Western European',
#  'Jewish',
#  'East Asian',
#  'Western European',
#  'Indian',
#  'Jewish',
#  'Hispanic',
#  'Hispanic',
#  'Western European',
#  'Indian',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Hispanic',
#  'Western European',
#  'East Asian',
#  'Jewish',
#  'Western European',
#  'Muslim/Arabic',
#  'Hispanic',
#  'Western European',
#  'Western European',
#  'Eastern European',
#  'Western European',
#  'Indian',
#  'East Asian',
#  'Western European',
#  'Jewish',
#  'Eastern European',
#  'Indian',
#  'Hispanic',
#  'Hispanic',
#  'Eastern European',
#  'Western European',
#  'Western European',
#  'Hispanic',
#  'Jewish',
#  'Jewish',
#  'Western European',
#  'Hispanic',
#  'Muslim/Arabic',
#  'Muslim/Arabic',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Western European',
#  'East Asian',
#  'Western European',
#  'Jewish',
#  'Indian',
#  'Hispanic',
#  'Western European',
#  'Jewish',
#  'Jewish',
#  'Eastern European',
#  'Hispanic',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Eastern European',
#  'Jewish',
#  'East Asian',
#  'Western European',
#  'Hispanic',
#  'African',
#  'Western European',
#  'Hispanic',
#  'Jewish',
#  'Eastern European',
#  'Indian',
#  'Eastern European',
#  'Hispanic',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Indian',
#  'Hispanic',
#  'Eastern European',
#  'Muslim/Arabic',
#  'Western European',
#  'Indian',
#  'Western European',
#  'Muslim/Arabic',
#  'Hispanic',
#  'East Asian',
#  'Western European',
#  'Western European',
#  'Western European',
#  'African',
#  'Western European',
#  'East Asian',
#  'Western European',
#  'Jewish',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Eastern European',
#  'Jewish',
#  'Jewish',
#  'Western European',
#  'Hispanic',
#  'Western European',
#  'Hispanic',
#  'Western European',
#  'Jewish',
#  'Eastern European',
#  'Western European',
#  'Eastern European',
#  'Jewish',
#  'East Asian',
#  'Western European',
#  'Western European',
#  'Hispanic',
#  'Eastern European',
#  'Jewish',
#  'Western European',
#  'Eastern European',
#  'Muslim/Arabic',
#  'Eastern European',
#  'Western European',
#  'Hispanic',
#  'Eastern European',
#  'Western European',
#  'Eastern European',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Jewish',
#  'African',
#  'Jewish',
#  'Hispanic',
#  'Hispanic',
#  'Jewish',
#  'Western European',
#  'Hispanic',
#  'Jewish',
#  'Jewish',
#  'Western European',
#  'Eastern European',
#  'Indian',
#  'Western European',
#  'Western European',
#  'African',
#  'Muslim/Arabic',
#  'East Asian',
#  'Indian',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Jewish',
#  'Muslim/Arabic',
#  'Hispanic',
#  'Hispanic',
#  'Jewish',
#  'Eastern European',
#  'Jewish',
#  'Hispanic',
#  'Hispanic',
#  'Hispanic',
#  'Indian',
#  'Western European',
#  'Eastern European',
#  'Eastern European',
#  'Hispanic',
#  'Indian',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Muslim/Arabic',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Jewish',
#  'Jewish',
#  'Eastern European',
#  'Western European',
#  'Western European',
#  'Eastern European',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Eastern European',
#  'Jewish',
#  'Western European',
#  'Jewish',
#  'Hispanic',
#  'Western European',
#  'Western European',
#  'Hispanic',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Eastern European',
#  'Hispanic',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Hispanic',
#  'Western European',
#  'Western European',
#  'Indian',
#  'Western European',
#  'Western European',
#  'Indian',
#  'Jewish',
#  'Indian',
#  'East Asian',
#  'Muslim/Arabic',
#  'East Asian',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'East Asian',
#  'East Asian',
#  'Jewish',
#  'Indian',
#  'East Asian',
#  'Hispanic',
#  'Western European',
#  'Western European',
#  'Hispanic',
#  'Indian',
#  'Western European',
#  'Western European',
#  'Eastern European',
#  'Eastern European',
#  'Western European',
#  'Jewish',
#  'Muslim/Arabic',
#  'Hispanic',
#  'Eastern European',
#  'Jewish',
#  'Eastern European',
#  'Indian',
#  'Jewish',
#  'Jewish',
#  'Jewish',
#  'Western European',
#  'Muslim/Arabic',
#  'Eastern European',
#  'Western European',
#  'Western European',
#  'Indian',
#  'Indian',
#  'Western European',
#  'Indian',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Hispanic',
#  'Muslim/Arabic',
#  'Muslim/Arabic',
#  'Hispanic',
#  'Eastern European',
#  'Eastern European',
#  'Western European',
#  'Western European',
#  'Indian',
#  'Western European',
#  'Hispanic',
#  'Muslim/Arabic',
#  'Western European',
#  'Eastern European',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Hispanic',
#  'East Asian',
#  'Hispanic',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Jewish',
#  'Hispanic',
#  'Muslim/Arabic',
#  'Eastern European',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Hispanic',
#  'Western European',
#  'Indian',
#  'Jewish',
#  'Hispanic',
#  'Jewish',
#  'Eastern European',
#  'Western European',
#  'African',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Jewish',
#  'East Asian',
#  'Muslim/Arabic',
#  'Western European',
#  'Muslim/Arabic',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Indian',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'East Asian',
#  'Jewish',
#  'East Asian',
#  'Jewish',
#  'Jewish',
#  'East Asian',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Indian',
#  'Eastern European',
#  'Jewish',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Indian',
#  'Western European',
#  'Western European',
#  'Indian',
#  'Eastern European',
#  'Western European',
#  'Western European',
#  'African',
#  'East Asian',
#  'Western European',
#  'Western European',
#  'Hispanic',
#  'Western European',
#  'East Asian',
#  'Hispanic',
#  'African',
#  'Indian',
#  'Western European',
#  'Western European',
#  'East Asian',
#  'Western European',
#  'Eastern European',
#  'Jewish',
#  'Western European',
#  'Hispanic',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Hispanic',
#  'Muslim/Arabic',
#  'Muslim/Arabic',
#  'Jewish',
#  'Jewish',
#  'Western European',
#  'Eastern European',
#  'Hispanic',
#  'Jewish',
#  'Muslim/Arabic',
#  'Jewish',
#  'Hispanic',
#  'Indian',
#  'Hispanic',
#  'Hispanic',
#  'Western European',
#  'East Asian',
#  'Muslim/Arabic',
#  'East Asian',
#  'Western European',
#  'Western European',
#  'Jewish',
#  'East Asian',
#  'Hispanic',
#  'Indian',
#  'Muslim/Arabic',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Hispanic',
#  'Western European',
#  'Jewish',
#  'Western European',
#  'Western European',
#  'Western European',
#  'African',
#  'Muslim/Arabic',
#  'East Asian',
#  'Hispanic',
#  'Hispanic',
#  'Jewish',
#  'Western European',
#  'Muslim/Arabic',
#  'Western European',
#  'Western European',
#  'Western European',
#  'Western European',
#  ...]

# %%
df_voters['Ethnicity Prediction'] = ethnicity_predictions

# %%
df_voters.sample(15)[['LAST_NAME', 'Ethnicity Prediction']]
# Out:
#       LAST_NAME Ethnicity Prediction
# 399    Phillips     Western European
# 1654      Burch     Eastern European
# 2752      Smith     Western European
# 2783    SAVISKY               Jewish
# 4068     Arroyo             Hispanic
# 3729    Whatley     Eastern European
# 5055    VAUGHAN     Western European
# 1226  Kerlicker               Jewish
# 362      Palmer               Jewish
# 3345      Rioux     Western European
# 3221     Kersch               Jewish
# 4043       HILL               Jewish
# 1512     Powell     Western European
# 2612   Melville             Hispanic
# 1343     Norman     Western European
