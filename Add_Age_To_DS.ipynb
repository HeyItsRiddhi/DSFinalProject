# %%
import pandas as pd
import numpy as np
import datetime as DT

# %%
data = pd.read_csv('final.csv', sep=",", header = None)
# Out:
# /Users/riddhishah/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (2,8,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#View Data
data.head()
# Out:
#     0           1      2          3         4           5             6   \
# 0  NaN  FIRST_NAME  GEN16  LAST_NAME  district         dob  electiondate
# 1  0.0       Peter    1.0      Smith       MRT  08/17/1950    11/08/2016
# 2  1.0     MELANIE    1.0      HERTL       CLA  01/14/1982    11/08/2016
# 3  2.0       Nigel    0.0   Williams       HIL  05/13/1997           NaN
# 4  3.0        RYAN    1.0    STIMERS       MON  12/01/1974    11/08/2016
#
#        7          8      9           10          11         12  \
# 0  female         id  party     regyear  typeofvote        zip
# 1       M  111768698    REP  06/13/2000           E      34997
# 2       F  102865764    REP  01/09/2001           Y      32073
# 3       M  122514241    DEM  05/15/2015         NaN  336124352
# 4       M  113936692    NPA  12/18/2001           E      33040
#
#                      13          14         15        16       17  18
# 0  Ethnicity Prediction  Unnamed: 0          2         3        4  19
# ...

# %%
#length of the data
len(data)
# Out:
# 100001

# %%
#drop duplicate columns
data.drop([0,14,15,16,17], axis=1, inplace=True)
data.head()
# Out:
#            1      2          3         4           5             6       7   \
# 0  FIRST_NAME  GEN16  LAST_NAME  district         dob  electiondate  female
# 1       Peter    1.0      Smith       MRT  08/17/1950    11/08/2016       M
# 2     MELANIE    1.0      HERTL       CLA  01/14/1982    11/08/2016       F
# 3       Nigel    0.0   Williams       HIL  05/13/1997           NaN       M
# 4        RYAN    1.0    STIMERS       MON  12/01/1974    11/08/2016       M
#
#           8      9           10          11         12                    13  \
# 0         id  party     regyear  typeofvote        zip  Ethnicity Prediction
# 1  111768698    REP  06/13/2000           E      34997                Jewish
# 2  102865764    REP  01/09/2001           Y      32073      Western European
# 3  122514241    DEM  05/15/2015         NaN  336124352      Western European
# 4  113936692    NPA  12/18/2001           E      33040      Western European
#
#    18
# 0  19
# 1   5
# 2   5
# 3   3
# 4   5

# %%
#drop first row as it has the columns name
data.drop(data.index[0], inplace=True)

# %%
#label columns
#Name Columns
newcolumns = ["FIRST_NAME", "GEN16", "LAST_NAME",  "district", "dob", "electiondate", "female", "id","party",
              "regyear", "typeofvote",'zip','Prediction','Race']
data.columns = newcolumns

# %%
data.head()
# Out:
#   FIRST_NAME GEN16 LAST_NAME district         dob electiondate female  \
# 1      Peter   1.0     Smith      MRT  08/17/1950   11/08/2016      M
# 2    MELANIE   1.0     HERTL      CLA  01/14/1982   11/08/2016      F
# 3      Nigel   0.0  Williams      HIL  05/13/1997          NaN      M
# 4       RYAN   1.0   STIMERS      MON  12/01/1974   11/08/2016      M
# 5      Benny   1.0   Bennett      BAK  09/06/1965   11/08/2016      M
#
#           id party     regyear typeofvote        zip        Prediction  Race
# 1  111768698   REP  06/13/2000          E      34997            Jewish     5
# 2  102865764   REP  01/09/2001          Y      32073  Western European     5
# 3  122514241   DEM  05/15/2015        NaN  336124352  Western European     3
# 4  113936692   NPA  12/18/2001          E      33040  Western European     5
# 5  100592058   REP  11/17/1983          Y      32087  Western European     5

# %%
data['dob'][0+1]
# Out:
# '08/17/1950'

# %%
from dateutil.relativedelta import relativedelta
#Add an age column
data['age'] = data.apply(lambda _: '', axis=1)
nan_count = 0
now = now = DT.datetime.now()

for i ,dob in enumerate(data['dob']):
    if (str(dob) == 'nan'):
        print(i)
        print(dob)
        nan_count += 1  
    else:
        data['dob'][i+1] = DT.datetime.strptime(str(dob), "%m/%d/%Y")
        rdelta = relativedelta(now,data['dob'][i+1])
        data['age'][i+1] = rdelta.years
# Out:
# /Users/riddhishah/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /Users/riddhishah/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# 422
# nan
# 497
# nan
# 1010
# nan
# 1061
# nan
# 1189
# nan
# 1313
# nan
# 1323
# nan
# 1333
# nan
# 1637
# nan
# 1653
# nan
# 1775
# nan
# 1960
# nan
# 2092
# nan
# 2459
# nan
# 2804
# nan
# 3160
# nan
# 3202
# nan
# 3475
# nan
# 3556
# nan
# 3945
# nan
# 3966
# nan
# 4195
# nan
# 4225
# nan
# 4835
# nan
# 5076
# nan
# 5125
# ...

# %%
data.head()
# Out:
#   FIRST_NAME GEN16 LAST_NAME district                  dob electiondate  \
# 1      Peter   1.0     Smith      MRT  1950-08-17 00:00:00   11/08/2016
# 2    MELANIE   1.0     HERTL      CLA  1982-01-14 00:00:00   11/08/2016
# 3      Nigel   0.0  Williams      HIL  1997-05-13 00:00:00          NaN
# 4       RYAN   1.0   STIMERS      MON  1974-12-01 00:00:00   11/08/2016
# 5      Benny   1.0   Bennett      BAK  1965-09-06 00:00:00   11/08/2016
#
#   female         id party     regyear typeofvote        zip        Prediction  \
# 1      M  111768698   REP  06/13/2000          E      34997            Jewish
# 2      F  102865764   REP  01/09/2001          Y      32073  Western European
# 3      M  122514241   DEM  05/15/2015        NaN  336124352  Western European
# 4      M  113936692   NPA  12/18/2001          E      33040  Western European
# 5      M  100592058   REP  11/17/1983          Y      32087  Western European
#
#    Race age
# 1     5  67
# 2     5  35
# 3     3  20
# ...

# %%
len(dat)

# %%
#Create a CSV from sample df
subset_data.to_csv('age_dataset.csv', sep='\t')
